# %%
## might not use this because prof Fudge suggested google places + geocoding 
import requests
import json
from yelp.client import Client

api_key='iEOELeU7EAXfwnhiuuPpqlH7xX96J4zfITA4w2jEYsiqlB6yBAXxs9t2la-JAvkFOxUmcjHMKR7jGKKD9AlqJBG4qk_G2WGHQjbXCgjXjWJcVLnoBr_bAJo-uDnDXHYx'
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search'
 
# In the dictionary, term can take values like food, cafes or businesses like McDonalds
params = {'term':'smoothie','location':'New York City'}


# Making a get request to the API
req=requests.get(url, params=params, headers=headers)

# printing the text from the response 
parsed = json.loads(req.text)

#print(json.dumps(parsed, indent=4))

businesses = parsed["businesses"]
 
for business in businesses:
    print("Name:", business["name"])
    print("Rating:", business["rating"])
    print("Address:", " ".join(business["location"]["display_address"]))
    print("Phone:", business["phone"])
    print("\n")
# Out:
# Name: Hawa Smoothies
# Rating: 4.0
# Address: 181 E Broadway Ste A New York, NY 10002
# Phone: +16465901911
#
#
# Name: Juice Vitality
# Rating: 5.0
# Address: 192 1st Ave New York, NY 10009
# Phone: +12124770071
#
#
# Name: Tropical Smoothie Cafe
# Rating: 3.5
# Address: 1650 Richmond Ave Staten Island, NY 10314
# Phone: +17185244006
#
#
# Name: Juice Press
# Rating: 3.0
# Address: 117 Front St Equinox Dumbo Brooklyn, NY 11201
# Phone: +12127770034
#
#
# Name: Hawa Smoothies & Bubble Tea
# Rating: 4.5
# Address: 44 Willoughby St Downtown Brooklyn, NY 11201
# Phone: +16462047818
#
#
# Name: The Shanti Shack
# Rating: 5.0
# Address: 85 N 3rd St Brooklyn, NY 11249
# Phone: +13474639886
#
#
# Name: Jo Juice & Salad Bar
# Rating: 4.0
# Address: 1065 Bedford Ave Brooklyn, NY 11216
# Phone:
#
#
# Name: Cool Fresh Juice Bar
# Rating: 4.5
# Address: 2661 A Broadway New York, NY 10025
# Phone: +16467569928
#
#
# Name: Madhufalla Organic Juice & Smoothie Bar
# Rating: 4.5
# ...
